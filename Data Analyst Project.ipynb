# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
bank = pd.read_csv("C:/Users/nania/OneDrive/Documents/Datasets/Bank_Churn.csv")

# %%
bank.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
bank.shape
# Out:
# (10000, 14)

# %%
bank.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
bank['Exited'].value_counts()
# Out:
# Exited
# 0    7963
# 1    2037
# Name: count, dtype: int64

# %%
bank['Geography'].value_counts()
# Out:
# Geography
# France     5014
# Germany    2509
# Spain      2477
# Name: count, dtype: int64

# %%
bank.drop(columns=['RowNumber','CustomerId','Surname'],inplace=True)

# %% [markdown]
# bank.drop(columns['RowNumber','CustomerId','Surname'],inplace=True)

# %%
bank.head()
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2       0.00              1
# 1          608     Spain  Female   41       1   83807.86              1
# 2          502    France  Female   42       8  159660.80              3
# 3          699    France  Female   39       1       0.00              2
# 4          850     Spain  Female   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0          1               1        101348.88       1
# 1          0               1        112542.58       0
# 2          1               0        113931.57       1
# 3          0               0         93826.63       0
# 4          1               1         79084.10       0

# %%
bank = pd.get_dummies(bank, columns=['Geography','Gender'],drop_first=True) #converting categorical into Numericals and creating some dummy columns

# %%
bank['Geography_Germany']=bank['Geography_Germany'].astype(int)
bank['Geography_Spain']=bank['Geography_Spain'].astype(int)
bank['Gender_Male']=bank['Gender_Male'].astype(int)

# %%
bank.head()
# Out:
#    CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0          619   42       2       0.00              1          1
# 1          608   41       1   83807.86              1          0
# 2          502   42       8  159660.80              3          1
# 3          699   39       1       0.00              2          0
# 4          850   43       2  125510.82              1          1
#
#    IsActiveMember  EstimatedSalary  Exited  Geography_Germany  \
# 0               1        101348.88       1                  0
# 1               1        112542.58       0                  0
# 2               0        113931.57       1                  0
# 3               0         93826.63       0                  0
# 4               1         79084.10       0                  0
#
#    Geography_Spain  Gender_Male
# 0                0            0
# 1                1            0
# 2                0            0
# 3                0            0
# 4                1            0

# %%
x=bank.drop(columns=['Exited']) #Inputs
y=bank['Exited'] #Output

# %%
x
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619   42       2       0.00              1          1
# 1             608   41       1   83807.86              1          0
# 2             502   42       8  159660.80              3          1
# 3             699   39       1       0.00              2          0
# 4             850   43       2  125510.82              1          1
# ...           ...  ...     ...        ...            ...        ...
# 9995          771   39       5       0.00              2          1
# 9996          516   35      10   57369.61              1          1
# 9997          709   36       7       0.00              1          0
# 9998          772   42       3   75075.31              2          1
# 9999          792   28       4  130142.79              1          1
#
#       IsActiveMember  EstimatedSalary  Geography_Germany  Geography_Spain  \
# 0                  1        101348.88                  0                0
# ...

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=42) #80% for training and 20% for testing

# %%
x_train
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 9254          686   32       6       0.00              2          1
# 1561          632   42       4  119624.60              2          1
# 1670          559   24       3  114739.92              1          1
# 6087          561   27       9  135637.00              1          1
# 6669          517   56       9  142147.32              1          0
# ...           ...  ...     ...        ...            ...        ...
# 5734          768   54       8   69712.74              1          1
# 5191          682   58       1       0.00              1          1
# 5390          735   38       1       0.00              3          0
# 860           667   43       8  190227.46              1          1
# 7270          697   51       1  147910.30              1          1
#
#       IsActiveMember  EstimatedSalary  Geography_Germany  Geography_Spain  \
# 9254               1        179093.26                  0                0
# ...

# %%
from sklearn.preprocessing import StandardScaler
scaler= StandardScaler()

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_train_trf =scaler.fit_transform(x_train)
x_test_trf = scaler.transform(x_test)

# %%
x_train_trf
# Out:
# array([[ 0.35649971, -0.6557859 ,  0.34567966, ..., -0.57946723,
#         -0.57638802,  0.91324755],
#        [-0.20389777,  0.29493847, -0.3483691 , ...,  1.72572313,
#         -0.57638802,  0.91324755],
#        [-0.96147213, -1.41636539, -0.69539349, ..., -0.57946723,
#          1.73494238,  0.91324755],
#        ...,
#        [ 0.86500853, -0.08535128, -1.38944225, ..., -0.57946723,
#         -0.57638802, -1.09499335],
#        [ 0.15932282,  0.3900109 ,  1.03972843, ..., -0.57946723,
#         -0.57638802,  0.91324755],
#        [ 0.47065475,  1.15059039, -1.38944225, ...,  1.72572313,
#         -0.57638802,  0.91324755]])

# %%
pip install --upgrade tensorflow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import tensorflow
from tensorflow import keras
from tensorflow.keras import sequential
from tensorflow.keras.layers import dense
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 import tensorflow
#       2 from tensorflow import keras
#       3 from tensorflow.keras import sequential
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
model = Sequential()
model.add(Dense(10, activation='relu', input_dim=11))
model.add(Dense(10,activation='relu'))
model.add(Dense(1,activation='sigmoid'))

# %%
model.summary()

# %%
model.complex(loss='binary_crossentropy',optimizer='Adam', metrics=['accuracy'])

# %%
history= model.fit(x_train_trf,y_train,epochs=50,validation_split=0.2)

# %%
model.layers[0].get_weights()

# %%
y_pred=model.predict(x_test_trf)

# %%
y_pred_enw=np.where(y_pred=0.5,1,0)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred_new)

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.show()

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.show()
